# %%
import warnings
warnings.filterwarnings("ignore")
from did_multiplegt_dyn import DidMultiplegtDyn
import pandas as pd
import time
import os
import polars as pl
os.chdir( r"/Users/anzony.quisperojas/Documents/GitHub/did_multiplegt_dyn_py" )

# %%
favara_imbs = pl.read_csv('https://raw.githubusercontent.com/anzonyquispe/py_did_multiplegt_dyn/main/data/favara_imbs_did_multiplegt_dyn.csv', 
                 ignore_errors = True)
start = time.time()
model1 = DidMultiplegtDyn(
    df=favara_imbs,
    outcome = "Dl_vloans_b",
    group = "county",
    time = "year",
    treatment = "inter_bra",
    effects = 8,
    placebo = 3,
    cluster = "state_n",
    normalized = True,
    same_switchers = True,
    effects_equal = True
)

# %%
model1.fit()

# %%
sum = model1.summary()
# Out:
#                Block  Estimate       SE     LB CI    UB CI      N  Switchers    N.w  Switchers.w
#             Effect_1  0.024039 0.018424 -0.012071 0.060150 3368.0      773.0 3368.0        773.0
#             Effect_2  0.011670 0.010671 -0.009245 0.032586 2604.0      773.0 2604.0        773.0
#             Effect_3  0.014344 0.008288 -0.001900 0.030589 2031.0      773.0 2031.0        773.0
#             Effect_4  0.011521 0.008195 -0.004541 0.027583 1541.0      773.0 1541.0        773.0
#             Effect_5  0.016163 0.006842  0.002753 0.029573 1412.0      773.0 1412.0        773.0
#             Effect_6  0.013386 0.006251  0.001134 0.025638 1293.0      773.0 1293.0        773.0
#             Effect_7  0.009810 0.004957  0.000094 0.019526 1248.0      773.0 1248.0        773.0
#             Effect_8  0.010084 0.004309  0.001638 0.018530 1248.0      773.0 1248.0        773.0
# Average_Total_Effect  0.055063 0.026808  0.002520 0.107606 9861.0     6184.0 9861.0       6184.0
#            Placebo_1  0.030379 0.026405 -0.021375 0.082132 2335.0      764.0 2335.0        764.0
#            Placebo_2 -0.021776 0.025352 -0.071466 0.027913  957.0      497.0  957.0        497.0
#            Placebo_3 -0.013711 0.026344 -0.065344 0.037921  511.0      358.0  511.0        358.0
# The development of this package was funded by the European Union.
# ERC REALLYCREDIBLE - GA N. 101043899

# %%
import matplotlib.pyplot as plt

# Your plot
model1.plot()
